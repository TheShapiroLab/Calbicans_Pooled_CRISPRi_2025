# %% [markdown]
# ## Load modules

# %% [raw]
# From the software tab, load scipy-stack/2023b

# %% [markdown]
# Close the notebook (using the open tabs menu) and restart

# %%
# !pip install --no-index seaborn
# Out:
# Looking in links: /cvmfs/soft.computecanada.ca/custom/python/wheelhouse/gentoo2023/x86-64-v3, /cvmfs/soft.computecanada.ca/custom/python/wheelhouse/gentoo2023/generic, /cvmfs/soft.computecanada.ca/custom/python/wheelhouse/generic
# Requirement already satisfied: seaborn in /localscratch/phidesp.53852516.0/lib/python3.11/site-packages (0.13.2+computecanada)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /home/phidesp/.local/lib/python3.11/site-packages (from seaborn) (2.1.1+computecanada)
# Requirement already satisfied: pandas>=1.2 in /home/phidesp/.local/lib/python3.11/site-packages (from seaborn) (2.2.2+computecanada)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /cvmfs/soft.computecanada.ca/easybuild/software/2023/x86-64-v3/Compiler/gcccore/scipy-stack/2024b/lib/python3.11/site-packages (from seaborn) (3.9.2+computecanada)
# Requirement already satisfied: contourpy>=1.0.1 in /cvmfs/soft.computecanada.ca/easybuild/software/2023/x86-64-v3/Compiler/gcccore/scipy-stack/2024b/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.0+computecanada)
# Requirement already satisfied: cycler>=0.10 in /cvmfs/soft.computecanada.ca/easybuild/software/2023/x86-64-v3/Compiler/gcccore/scipy-stack/2024b/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1+computecanada)
# Requirement already satisfied: fonttools>=4.22.0 in /cvmfs/soft.computecanada.ca/easybuild/software/2023/x86-64-v3/Compiler/gcccore/scipy-stack/2024b/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.53.1+computecanada)
# Requirement already satisfied: kiwisolver>=1.3.1 in /cvmfs/soft.computecanada.ca/easybuild/software/2023/x86-64-v3/Compiler/gcccore/scipy-stack/2024b/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7+computecanada)
# Requirement already satisfied: packaging>=20.0 in /cvmfs/soft.computecanada.ca/easybuild/software/2023/x86-64-v3/Compiler/gcccore/scipy-stack/2024b/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1+computecanada)
# Requirement already satisfied: pillow>=8 in /cvmfs/soft.computecanada.ca/easybuild/software/2023/x86-64-v3/Compiler/gcccore/scipy-stack/2024b/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.4.0+computecanada)
# Requirement already satisfied: pyparsing>=2.3.1 in /cvmfs/soft.computecanada.ca/easybuild/software/2023/x86-64-v3/Compiler/gcccore/scipy-stack/2024b/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.4+computecanada)
# Requirement already satisfied: python-dateutil>=2.7 in /home/phidesp/.local/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0+computecanada)
# Requirement already satisfied: pytz>=2020.1 in /home/phidesp/.local/lib/python3.11/site-packages (from pandas>=1.2->seaborn) (2024.2+computecanada)
# Requirement already satisfied: tzdata>=2022.7 in /home/phidesp/.local/lib/python3.11/site-packages (from pandas>=1.2->seaborn) (2024.2+computecanada)
# Requirement already satisfied: six>=1.5 in /cvmfs/soft.computecanada.ca/easybuild/software/2023/x86-64-v3/Compiler/gcccore/scipy-stack/2024b/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0+computecanada)

# %% [markdown]
# ## Import packages

# %%
import numpy as np
import pandas as pd
import math as math
import matplotlib.pyplot as plt
import subprocess
import os
import scipy.stats as stats
from collections import Counter

import seaborn as sns

import warnings
warnings.simplefilter(action='ignore', category=pd.errors.PerformanceWarning)

# %% [markdown]
# Import your sample datasheet. If you have already run part of the notebook, some additional columns might be there.

# %%
sample_datasheet = pd.read_csv('./sample_datasheet_updated.csv', sep=',', index_col=0)
sample_datasheet
# Out:
#        strain timepoint     condition  Drug  ATC  replicate  \
# sample
# 1          WT        T0           YPD   NaN   No          1
# 2          WT        T0           YPD   NaN   No          2
# 3          WT        T0           YPD   NaN   No          3
# 4          WT        T3           YPD    No   No          1
# 5          WT        T3           YPD    No   No          2
# 6          WT        T3           YPD    No   No          3
# 7          WT        T3      YPD_CASP  Casp   No          1
# 8          WT        T3      YPD_CASP  Casp   No          2
# 9          WT        T3      YPD_CASP  Casp   No          3
# 10         WT        T0       YPD_ATC   NaN  Yes          1
# 11         WT        T0       YPD_ATC   NaN  Yes          2
# 12         WT        T0       YPD_ATC   NaN  Yes          3
# 13         WT        T3       YPD_ATC    No  Yes          1
# 14         WT        T3       YPD_ATC    No  Yes          2
# 15         WT        T3       YPD_ATC    No  Yes          3
# 16         WT        T3  YPD_ATC_CASP  Casp  Yes          1
# 17         WT        T3  YPD_ATC_CASP  Casp  Yes          2
# 18         WT        T3  YPD_ATC_CASP  Casp  Yes          3
# 19        ARB        T0           YPD   NaN   No          1
# 20        ARB        T0           YPD   NaN   No          2
# 21        ARB        T0           YPD   NaN   No          3
# 22        ARB        T3           YPD    No   No          1
# 23        ARB        T3           YPD    No   No          2
# 24        ARB        T3           YPD    No   No          3
# 25        ARB        T3      YPD_CASP  Casp   No          1
# 26        ARB        T3      YPD_CASP  Casp   No          2
# 27        ARB        T3      YPD_CASP  Casp   No          3
# 28        ARB        T0       YPD_ATC   NaN  Yes          1
# 29        ARB        T0       YPD_ATC   NaN  Yes          2
# 30        ARB        T0       YPD_ATC   NaN  Yes          3
# 31        ARB        T3       YPD_ATC    No  Yes          1
# 32        ARB        T3       YPD_ATC    No  Yes          2
# 33        ARB        T3       YPD_ATC    No  Yes          3
# 34        ARB        T3  YPD_ATC_CASP  Casp  Yes          1
# 35        ARB        T3  YPD_ATC_CASP  Casp  Yes          2
# 36        ARB        T3  YPD_ATC_CASP  Casp  Yes          3
# 37        ERB        T0           YPD   NaN   No          1
# 38        ERB        T0           YPD   NaN   No          2
# 39        ERB        T0           YPD   NaN   No          3
# 40        ERB        T3           YPD    No   No          1
# 41        ERB        T3           YPD    No   No          2
# 42        ERB        T3           YPD    No   No          3
# 43        ERB        T3      YPD_CASP  Casp   No          1
# 44        ERB        T3      YPD_CASP  Casp   No          2
# 45        ERB        T3      YPD_CASP  Casp   No          3
# 46        ERB        T0       YPD_ATC   NaN  Yes          1
# 47        ERB        T0       YPD_ATC   NaN  Yes          2
# 48        ERB        T0       YPD_ATC   NaN  Yes          3
# 49        ERB        T3       YPD_ATC    No  Yes          1
# 50        ERB        T3       YPD_ATC    No  Yes          2
# 51        ERB        T3       YPD_ATC    No  Yes          3
# 52        ERB        T3  YPD_ATC_CASP  Casp  Yes          1
# 53        ERB        T3  YPD_ATC_CASP  Casp  Yes          2
# 54        ERB        T3  YPD_ATC_CASP  Casp  Yes          3
#
#                      fastq_path  raw_reads  assembled_reads
# sample
# 1         ./data/WT-1_S169_L001     543199           511237
# 2         ./data/WT-2_S170_L001     613699           563118
# 3         ./data/WT-3_S171_L001     492029           466635
# 4         ./data/WT-4_S172_L001     514401           477197
# 5         ./data/WT-5_S173_L001     548335           516723
# 6         ./data/WT-6_S174_L001     560684           513004
# 7        ./data/WT-10_S178_L001     644818           583766
# 8        ./data/WT-11_S179_L001     486498           456824
# 9        ./data/WT-12_S180_L001     561766           525969
# 10       ./data/WT-13_S181_L001     552371           487212
# 11       ./data/WT-14_S182_L001     637531           553729
# 12       ./data/WT-15_S183_L001     454598           398548
# 13       ./data/WT-16_S184_L001     523029           483391
# 14       ./data/WT-17_S185_L001     534582           484856
# 15       ./data/WT-18_S186_L001     585025           515302
# 16       ./data/WT-22_S190_L001     474785           433718
# 17       ./data/WT-23_S191_L001     405460           361950
# 18       ./data/WT-24_S192_L001     479340           436431
# 19       ./data/ARB-1_S121_L001     906389           853085
# 20       ./data/ARB-2_S122_L001     882164           832667
# 21       ./data/ARB-3_S123_L001     576132           554237
# 22       ./data/ARB-4_S124_L001     776756           753113
# 23       ./data/ARB-5_S125_L001     752120           728901
# 24       ./data/ARB-6_S126_L001     869161           824518
# 25      ./data/ARB-10_S130_L001     860229           828723
# 26      ./data/ARB-11_S131_L001     849336           820350
# 27      ./data/ARB-12_S132_L001    1054031          1008024
# 28      ./data/ARB-13_S133_L001     887791           848836
# 29      ./data/ARB-14_S134_L001     671685           652075
# 30      ./data/ARB-15_S135_L001     875768           857668
# 31      ./data/ARB-16_S136_L001     212707           206861
# 32      ./data/ARB-17_S137_L001     850052           827066
# 33      ./data/ARB-18_S138_L001     951690           914188
# 34      ./data/ARB-22_S142_L001     947849           915726
# 35      ./data/ARB-23_S143_L001     892455           862012
# 36      ./data/ARB-24_S144_L001     997066           962008
# 37       ./data/ERB-1_S145_L001     554012           529425
# 38       ./data/ERB-2_S146_L001     676290           650373
# 39       ./data/ERB-3_S147_L001     626529           589738
# 40       ./data/ERB-4_S148_L001     697972           663995
# 41       ./data/ERB-5_S149_L001     795392           768001
# 42       ./data/ERB-6_S150_L001     529855           486751
# 43      ./data/ERB-10_S154_L001     567566           556607
# 44      ./data/ERB-11_S155_L001     563085           546270
# 45      ./data/ERB-12_S156_L001     773365           742960
# 46      ./data/ERB-13_S157_L001     264744           259163
# 47      ./data/ERB-14_S158_L001     725657           701421
# 48      ./data/ERB-15_S159_L001     389759           381001
# 49      ./data/ERB-16_S160_L001     445880           431370
# 50      ./data/ERB-17_S161_L001     563509           548689
# 51      ./data/ERB-18_S162_L001     551704           534340
# 52      ./data/ERB-22_S166_L001     514470           502706
# 53      ./data/ERB-23_S167_L001     460979           450933
# 54      ./data/ERB-24_S168_L001     652653           631783

# %% [markdown]
# ## Get the number of raw reads for each file (run once then skip afterwards)

# %%
raw_read_count_dict = {}
# empty dictionnary to hold the library:n_reads info

for sample in sample_datasheet.index:
    # loop through samples in datasheet
    
    R1_fastq_path = sample_datasheet.at[sample,'fastq_path']+'_R1_001.fastq.gz'
    # path to the fasq file 
    command = 'zgrep -o \'@VL\' '+R1_fastq_path+' | wc -l'
    # command to count number of fastq headers in the file, header guide from: https://www.biostars.org/p/198143/#198150 
    # @HWI-Mxxxx or @Mxxxx - MiSeq
    # @HWUSI - GAIIx
    # @HWI-Dxxxx - HiSeq 2000/2500
    # @Kxxxx - HiSeq 3000(?)/4000
    # @Nxxxx - NextSeq 500/550
    # @Axxxxx - NovaSeq
    # @Vxxxxx = NextSeq 2000
    # Edit (08/2022)
    # @AAxxxxx - NextSeq 2000 P1/P2/P3
    # @Hxxxxxx - NovaSeq S1/S2/S4
    
    output  = subprocess.check_output('zgrep -o \'@VL\' '+R1_fastq_path+' | wc -l', shell=True, text=True)
    raw_read_count_dict[sample] = int(output.strip('\n'))
    # run the command and store the output
    
sample_datasheet['raw_reads'] = pd.Series(raw_read_count_dict)
    
sample_datasheet.to_csv('./exemple_csv.csv', sep=',')
    
# this step takes ~18s to complete for a 3M read dataset, so expect run time to scale accordingly. 
# To avoid redoing it, we save the dataframe after finishing this step -> 10M reads/min

# %%
sum(raw_read_count_dict.values())
# total number of reads sequenced
# Out:
# 34778952

# %%
plt.bar([x for x in sample_datasheet.index], [sample_datasheet.at[x, 'raw_reads'] for x in sample_datasheet.index])
plt.axhline(np.median([sample_datasheet.at[x, 'raw_reads'] for x in sample_datasheet.index]), color='r', linestyle='--')
plt.xlabel('Sample')
plt.ylabel('Number of reads')
# Out:
# Text(0, 0.5, 'Number of reads')

# %% [markdown]
# ## Prepare directories

# %%
list_dir = os.listdir()

if 'logs' not in list_dir:
    os.mkdir('logs')
if 'fastqc_outputs' not in list_dir:
    os.mkdir('fastqc_outputs')
if 'pear_output' not in list_dir:
    os.mkdir('pear_output')
if 'vsearch_trim' not in list_dir:
    os.mkdir('vsearch_trim')
if 'vsearch_aggregate' not in list_dir:
    os.mkdir('vsearch_aggregate')
if 'barcode_counts' not in list_dir:
    os.mkdir('barcode_counts')
# If they are not already present, create directories for intermediate analysis files

# %% [markdown]
# ## Write bash script to run FastQC on samples (QC for sequencer output)
# Change the time as a function of the number of reads. A 14 * 0.85M test dataset took about 33s, so about 1.4M reads/min. Consider increasing the runtime if you have > 85M reads per sample.

# %%
n_files = len(sample_datasheet.index)*2
print(n_files)

with open('./run_fastqc.sh', 'w') as dest:
    
    

    dest.write('#!/bin/bash'+'\n')                         # bash header
    dest.write('#SBATCH --account=def-rshap'+'\n')         # compute canada PI account
    dest.write('#SBATCH --cpus-per-task='+str(n_files+1)+'\n')          # number of cpus for the job
    dest.write('#SBATCH --mem='+str(math.ceil(((n_files+1)*0.5)))+'G\n')                    # RAM for the job
    dest.write('#SBATCH --time=0-01:00'+'\n')              # time limit
    dest.write('#SBATCH --output=logs/slurm-%j.out'+'\n')  # directory to store logs limit
    dest.write('\n'+'\n')
    
    dest.write('module load fastqc'+'\n')
    # load the fastqc module
    
    fastqc_command = 'fastqc --outdir fastqc_outputs -t '+str(n_files)+ ' --extract --delete ./data/*.fastq.gz'
    dest.write(fastqc_command)
# Out:
# 108

# %% [markdown]
# ## Write bash script
# Change the time as a function of the number of reads. A 3M test dataset took about 5 mins and 3 GB of RAM, so about 0.6M reads/million reads and 1 GB RAM per million reads.

# %%
with open('./process_barcodes.sh', 'w') as dest:
    dest.write('#!/bin/bash'+'\n')                         # bash header
    dest.write('#SBATCH --account=def-rshap'+'\n')         # compute canada PI account
    dest.write('#SBATCH --cpus-per-task=16'+'\n')          # number of cpus for the job
    dest.write('#SBATCH --mem=5G'+'\n')                    # RAM for the job
    dest.write('#SBATCH --time=0-02:00'+'\n')              # time limit
    dest.write('#SBATCH --output=logs/slurm-%j.out'+'\n')  # directory to store logs limit
    dest.write('\n'+'\n')
    
    dest.write('module load StdEnv/2020'+'\n') # load software modules 
    
    dest.write('module load pear'+'\n')
    dest.write('module load vsearch'+'\n')
    
    for sample in sample_datasheet.index:
        dest.write('date'+'\n')
        fastq_path = sample_datasheet.at[sample, 'fastq_path']
        fastq_R1 = fastq_path +'_R1_001.fastq.gz'
        fastq_R2 = fastq_path +'_R2_001.fastq.gz'
        pear_out = './pear_output/'+str(sample)
        
        pear_command = 'pear -f '+fastq_R1+' -r '+fastq_R2+' -o '+pear_out+' -j 16 -u 0.01 -q 20 -m 154 -n 145'+'\n'
        dest.write(pear_command)
        
        assembled_reads = './pear_output/'+str(sample)+'.assembled.fastq'
        dest.write('date'+'\n')
        
        filter_out = './vsearch_trim/'+str(sample)+'_trimmed.fastq'
        filter_rc = './vsearch_trim/'+str(sample)+'_trimmed_rc.fastq'
        
        filter_command = 'vsearch --fastx_filter '+assembled_reads+' --fastq_stripleft 20 --fastq_stripright 43 --fastaout '+filter_out+'\n'
        rc_command = 'vsearch --fastx_revcomp '+filter_out+' --fastaout '+filter_rc+'\n'
        
        dest.write(filter_command)
        dest.write(rc_command)
        
        dest.write('date'+'\n')
        
        aggregate_fasta = './vsearch_aggregate/'+str(sample)+'_aggregate.fasta'
        aggregate_command = 'vsearch --derep_fulllength '+filter_rc+' --relabel seq --output '+aggregate_fasta+' --sizeout'+'\n'
        
        dest.write(aggregate_command)
        
    dest.write('date'+'\n')

# %%
assembled_read_count = {}

for sample in sample_datasheet.index:
    assembled_reads = './pear_output/'+str(sample)+'.assembled.fastq'
    command = 'grep -o \'@VL\' '+assembled_reads+' | wc -l'
    
    output  = subprocess.check_output(command, shell=True, text=True)
    assembled_read_count[sample] = int(output.strip('\n'))
    
sample_datasheet['assembled_reads'] = pd.Series(assembled_read_count)
    
sample_datasheet.to_csv('./sample_datasheet_updated.csv', sep=',')

# %%
sample_datasheet
# Out:
#        strain timepoint     condition  Drug  ATC  replicate  \
# sample
# 1          WT        T0           YPD   NaN   No          1
# 2          WT        T0           YPD   NaN   No          2
# 3          WT        T0           YPD   NaN   No          3
# 4          WT        T3           YPD    No   No          1
# 5          WT        T3           YPD    No   No          2
# 6          WT        T3           YPD    No   No          3
# 7          WT        T3      YPD_CASP  Casp   No          1
# 8          WT        T3      YPD_CASP  Casp   No          2
# 9          WT        T3      YPD_CASP  Casp   No          3
# 10         WT        T0       YPD_ATC   NaN  Yes          1
# 11         WT        T0       YPD_ATC   NaN  Yes          2
# 12         WT        T0       YPD_ATC   NaN  Yes          3
# 13         WT        T3       YPD_ATC    No  Yes          1
# 14         WT        T3       YPD_ATC    No  Yes          2
# 15         WT        T3       YPD_ATC    No  Yes          3
# 16         WT        T3  YPD_ATC_CASP  Casp  Yes          1
# 17         WT        T3  YPD_ATC_CASP  Casp  Yes          2
# 18         WT        T3  YPD_ATC_CASP  Casp  Yes          3
# 19        ARB        T0           YPD   NaN   No          1
# 20        ARB        T0           YPD   NaN   No          2
# 21        ARB        T0           YPD   NaN   No          3
# 22        ARB        T3           YPD    No   No          1
# 23        ARB        T3           YPD    No   No          2
# 24        ARB        T3           YPD    No   No          3
# 25        ARB        T3      YPD_CASP  Casp   No          1
# 26        ARB        T3      YPD_CASP  Casp   No          2
# 27        ARB        T3      YPD_CASP  Casp   No          3
# 28        ARB        T0       YPD_ATC   NaN  Yes          1
# 29        ARB        T0       YPD_ATC   NaN  Yes          2
# 30        ARB        T0       YPD_ATC   NaN  Yes          3
# 31        ARB        T3       YPD_ATC    No  Yes          1
# 32        ARB        T3       YPD_ATC    No  Yes          2
# 33        ARB        T3       YPD_ATC    No  Yes          3
# 34        ARB        T3  YPD_ATC_CASP  Casp  Yes          1
# 35        ARB        T3  YPD_ATC_CASP  Casp  Yes          2
# 36        ARB        T3  YPD_ATC_CASP  Casp  Yes          3
# 37        ERB        T0           YPD   NaN   No          1
# 38        ERB        T0           YPD   NaN   No          2
# 39        ERB        T0           YPD   NaN   No          3
# 40        ERB        T3           YPD    No   No          1
# 41        ERB        T3           YPD    No   No          2
# 42        ERB        T3           YPD    No   No          3
# 43        ERB        T3      YPD_CASP  Casp   No          1
# 44        ERB        T3      YPD_CASP  Casp   No          2
# 45        ERB        T3      YPD_CASP  Casp   No          3
# 46        ERB        T0       YPD_ATC   NaN  Yes          1
# 47        ERB        T0       YPD_ATC   NaN  Yes          2
# 48        ERB        T0       YPD_ATC   NaN  Yes          3
# 49        ERB        T3       YPD_ATC    No  Yes          1
# 50        ERB        T3       YPD_ATC    No  Yes          2
# 51        ERB        T3       YPD_ATC    No  Yes          3
# 52        ERB        T3  YPD_ATC_CASP  Casp  Yes          1
# 53        ERB        T3  YPD_ATC_CASP  Casp  Yes          2
# 54        ERB        T3  YPD_ATC_CASP  Casp  Yes          3
#
#                      fastq_path  raw_reads  assembled_reads
# sample
# 1         ./data/WT-1_S169_L001     543199           511237
# 2         ./data/WT-2_S170_L001     613699           563118
# 3         ./data/WT-3_S171_L001     492029           466635
# 4         ./data/WT-4_S172_L001     514401           477197
# 5         ./data/WT-5_S173_L001     548335           516723
# 6         ./data/WT-6_S174_L001     560684           513004
# 7        ./data/WT-10_S178_L001     644818           401963
# 8        ./data/WT-11_S179_L001     486498           496228
# 9        ./data/WT-12_S180_L001     561766           524126
# 10       ./data/WT-13_S181_L001     552371           583766
# 11       ./data/WT-14_S182_L001     637531           456824
# 12       ./data/WT-15_S183_L001     454598           525969
# 13       ./data/WT-16_S184_L001     523029           487212
# 14       ./data/WT-17_S185_L001     534582           553729
# 15       ./data/WT-18_S186_L001     585025           398548
# 16       ./data/WT-22_S190_L001     474785           483391
# 17       ./data/WT-23_S191_L001     405460           484856
# 18       ./data/WT-24_S192_L001     479340           515302
# 19       ./data/ARB-1_S121_L001     906389           520196
# 20       ./data/ARB-2_S122_L001     882164           425708
# 21       ./data/ARB-3_S123_L001     576132           334972
# 22       ./data/ARB-4_S124_L001     776756           433718
# 23       ./data/ARB-5_S125_L001     752120           361950
# 24       ./data/ARB-6_S126_L001     869161           436431
# 25      ./data/ARB-10_S130_L001     860229           853085
# 26      ./data/ARB-11_S131_L001     849336           832667
# 27      ./data/ARB-12_S132_L001    1054031           554237
# 28      ./data/ARB-13_S133_L001     887791           753113
# 29      ./data/ARB-14_S134_L001     671685           728901
# 30      ./data/ARB-15_S135_L001     875768           824518
# 31      ./data/ARB-16_S136_L001     212707           618600
# 32      ./data/ARB-17_S137_L001     850052           831083
# 33      ./data/ARB-18_S138_L001     951690           711574
# 34      ./data/ARB-22_S142_L001     947849           828723
# 35      ./data/ARB-23_S143_L001     892455           820350
# 36      ./data/ARB-24_S144_L001     997066          1008024
# 37       ./data/ERB-1_S145_L001     554012           848836
# 38       ./data/ERB-2_S146_L001     676290           652075
# 39       ./data/ERB-3_S147_L001     626529           857668
# 40       ./data/ERB-4_S148_L001     697972           206861
# 41       ./data/ERB-5_S149_L001     795392           827066
# 42       ./data/ERB-6_S150_L001     529855           914188
# 43      ./data/ERB-10_S154_L001     567566           817769
# 44      ./data/ERB-11_S155_L001     563085           649373
# 45      ./data/ERB-12_S156_L001     773365           697322
# 46      ./data/ERB-13_S157_L001     264744           915726
# 47      ./data/ERB-14_S158_L001     725657           862012
# 48      ./data/ERB-15_S159_L001     389759           962008
# 49      ./data/ERB-16_S160_L001     445880           529425
# 50      ./data/ERB-17_S161_L001     563509           650373
# 51      ./data/ERB-18_S162_L001     551704           589738
# 52      ./data/ERB-22_S166_L001     514470           663995
# 53      ./data/ERB-23_S167_L001     460979           768001
# 54      ./data/ERB-24_S168_L001     652653           486751

# %%
plt.bar([x for x in sample_datasheet.index], [sample_datasheet.at[x, 'assembled_reads'] for x in sample_datasheet.index])
plt.xlabel('Sample')
plt.ylabel('Number of merged reads')
# Out:
# Text(0, 0.5, 'Number of merged reads')

# %%
merge_stats = stats.linregress(sample_datasheet.raw_reads, sample_datasheet.assembled_reads)

# %%
plt.figure(figsize=(6,6))
plt.scatter(sample_datasheet.raw_reads, sample_datasheet.assembled_reads)

plt.plot([250000, 850000], [250000, 850000], '-k')

plt.xlabel('Number of raw reads')
plt.ylabel('Number of merged reads')

plt.plot([x for x in range(250000, 900000, 50000)], [(x*merge_stats[0])+merge_stats[1] for x in range(250000, 900000, 50000)], 'r--')

# %% [markdown]
# ## Import sgRNA/barcode dataframe

# %%
sgRNA_df = pd.read_csv('./sgrna_annot.csv', index_col=0)
sgRNA_df
# Out:
#                   Gene alias  SgRNA                  Barcode  control strand  \
# 0            C1_00220W  PHR2      1     TTGGCTTTCCTCCCCTTAAC        0      +
# 1            C1_00220W  PHR2      2     TCCTTGAATTTCTTGGTAGA        0      -
# 2            C1_00220W  PHR2      3     CGATGATTCCTTGAATTTCT        0      -
# 3            C1_00220W  PHR2      4     CAACAGTAGCAGAATTGTAC        0      +
# 4            C1_00400W  SVF1      5     TTAATGTCGCTTAGTGATGG        0      -
# ..                 ...   ...    ...                      ...      ...    ...
# 548         R-sgRNA 27   NaN    551     GGTATCGTCGTGTCTCATTA        1    NaN
# 549         R-sgRNA 28   NaN    552     CGCGTCCAGGTTCTTCTGGA        1    NaN
# 550         R-sgRNA 29   NaN    553     TGTTGGATCGTCCCTAGGAA        1    NaN
# 551         R-sgRNA 30   NaN    554     TCTGACGATCTGTTGTGAGA        1    NaN
# 552  Plasmid Backbone    NaN    555  TGAAGAGCCATTAATGCTCTTCC        2    NaN
#
#      atg_dist B_mismatch  dist_TSS  abs_TSS_dist  GC_content
# 0       112.0         no      -9.0           9.0   50.000000
# 1        45.0         no      58.0          58.0   35.000000
# 2        38.0         no      65.0          65.0   35.000000
# 3       288.0         no    -185.0         185.0   40.000000
# 4       177.0         no     -89.0          89.0   40.000000
# ..        ...        ...       ...           ...         ...
# 548       NaN         no       NaN           NaN   45.000000
# 549       NaN         no       NaN           NaN   60.000000
# 550       NaN         no       NaN           NaN   50.000000
# 551       NaN         no       NaN           NaN   45.000000
# 552       NaN         no       NaN           NaN   43.478261
#
# [553 rows x 11 columns]

# %%
non_count_cols = list(sgRNA_df.columns)
# list of columns present in the starting dataframe

# %%
def get_dict_of_seq(fasta_file):
    """ function that converts a fasta file to a dictionnary of sequences
    fasta_file: the input fasta file
    """
    
    file_fasta_dict = {}
    # output dict of imported seqs
    
    with open(fasta_file, 'r') as fasta:    
        for line in fasta:
            # loops through the file

            if line.startswith('>') == True:
                seq_info = line.strip('>').strip('\n').split('\t')[0]
                file_fasta_dict[seq_info] = ''
                # checks if seq header

            else:
                file_fasta_dict[seq_info] += line.strip('\n')
                # If not, append nt to current seq
                
    return file_fasta_dict

# %% [markdown]
# ## Count sgRNAs using perfect match, with a 8nt anchor

# %%
def count_barcodes_perfect_match(fasta_seq_dict, barcode_dict):
    # from a dictionnary of aggregate fasta entry and the sgRNA table, count the number of reads associated
    # with each guide, only counting perfect sequence matches to the sgRNA with an 8 nt "anchor" in 3' and 5'
    # to prevent +1/-1 shifted sgRNA from contaminating one another
       
    sample_sgRNA_counter = Counter()
    # empty counter to store sgRNA count values
    
    for key in list(fasta_seq_dict.keys()):
        # iterate trough aggregate sequences
        
        seq_count = int(key.split(';size=')[1])
        # get sequence counts for the fasta entry
        
        n_match = 0
        barcode_ids = []
        # containers for debugging
        
        for barcode in list(barcode_dict.keys()):
            # iterate through sgRNA sequences
            
            if "AATTTCGA"+barcode+"GTTTTAGA" in fasta_seq_dict[key]:
                # add 8nt in 5' and 3' to anchor the sgRNA
                n_match+=1
                barcode_ids.append(barcode)
                # increment match counter and match list for debugging
                if n_match > 1:
                    print(key, n_match, barcode_ids)
                    # print a warning if a sequence matches multiple sgRNAs
                    
                sample_sgRNA_counter[barcode_dict[barcode]] +=seq_count
                # add sgRNA count to Counter
                
            elif barcode == 'TGAAGAGCCATTAATGCTCTTCC':
                if 'GGAAGAGCATTAATGGCTCTTCA' in fasta_seq_dict[key]:
                    n_match+=1
                    barcode_ids.append(barcode)
                    # increment match counter and match list for debugging
                    if n_match > 1:
                        print(key, n_match, barcode_ids)
                        # print a warning if a sequence matches multiple sgRNAs
                    
                    sample_sgRNA_counter[barcode_dict[barcode]] +=seq_count
                    # add sgRNA count to Counter
                    
        if n_match>1:
            print(key)
                    
        #if seq_count>50 and n_match==0:
        #    print(key, fasta_seq_dict[key])
                    
    return sample_sgRNA_counter

# %%
3/0.66
# Out:
# 4.545454545454545

# %% [markdown]
# As it is, this takes ~40s for 3M reads, so about 4.5M reads per minute. Can be left to run on its own for a while if you have a very large dataset.

# %%
usable_reads_dict = {}

barcode_dict = {}

for sgRNA in sgRNA_df.index:
    barcode = sgRNA_df.at[sgRNA, 'Barcode']
    barcode_dict[barcode] = sgRNA

for sample in sample_datasheet.index:
    aggregate_fasta = './vsearch_aggregate/'+str(sample)+'_aggregate.fasta'
    fasta_dict = get_dict_of_seq(aggregate_fasta)
    
    
    
    
    sgRNA_counter = count_barcodes_perfect_match(fasta_dict, barcode_dict)
    usable_reads_dict[sample] = sum(sgRNA_counter.values())
    
    col_name = sample_datasheet.at[sample, 'strain']+'_'
    col_name += sample_datasheet.at[sample, 'timepoint']+'_'
    col_name += sample_datasheet.at[sample, 'condition']+'_'
    col_name += str(sample_datasheet.at[sample, 'replicate'])
    
    sgRNA_df[col_name] = pd.Series(sgRNA_counter)
    

    
#usable_reads_dict

# %%
pd.Series(sgRNA_counter)
# Out:
# 98     9577
# 538    9100
# 29     6898
# 121    5870
# 164    5684
#        ...
# 109       2
# 101       2
# 232       1
# 205       1
# 208       1
# Length: 536, dtype: int64

# %%
sample_datasheet['usable_reads'] = pd.Series(usable_reads_dict)
usable_stats = stats.linregress(sample_datasheet.raw_reads, sample_datasheet.usable_reads)
print(usable_stats)
# Out:
# LinregressResult(slope=np.float64(0.15700999263130824), intercept=np.float64(480515.31486584037), rvalue=np.float64(0.17117565211796124), pvalue=np.float64(0.2158626975270879), stderr=np.float64(0.125321590555972), intercept_stderr=np.float64(84008.40016779855))

# %%
plt.figure(figsize=(6,6))
plt.scatter(sample_datasheet.raw_reads, sample_datasheet.usable_reads)

plt.plot([200000, 900000], [200000, 900000], '-k')

plt.xlabel('Number of raw reads')
plt.ylabel('Number of usable counts')

plt.plot([x for x in range(200000, 900000, 5000)], [(x*usable_stats[0])+usable_stats[1] for x in range(200000, 900000, 5000)], 'r--')

# %%
plt.bar([x for x in sample_datasheet.index], [sample_datasheet.at[x, 'usable_reads'] for x in sample_datasheet.index])
plt.axhline(sample_datasheet['usable_reads'].median(), color='red')
plt.xlabel('Sample')
plt.ylabel('Number of usable reads')
# Out:
# Text(0, 0.5, 'Number of usable reads')

# %%
sgRNA_df.to_csv('./sgRNAs_annot_wcounts_clin_isolates.csv', sep=',')
